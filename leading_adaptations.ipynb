# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import load_dataset

# %%
df = pd.read_csv('ai_adoption_dataset.csv')
print(df.head())
print(df.info())
# Out:
#      country        industry           ai_tool  adoption_rate  \
# 0        USA      Technology           ChatGPT          40.45
# 1     France   Manufacturing        Midjourney          35.72
# 2  Australia  Transportation           ChatGPT          13.47
# 3         UK   Manufacturing           ChatGPT          48.46
# 4         UK     Agriculture  Stable Diffusion          34.06
#
#    daily_active_users  year  \
# 0                2461  2023
# 1                8496  2024
# 2                8641  2024
# 3                3488  2023
# 4                1124  2024
#
#                                        user_feedback age_group company_size
# 0  YyvLXOFyevRMSvJtkXodLvgejiqQNvSOZfeeJASDOVTxwm...     35-44      Startup
# 1  AdFVhenjthYSKJNzxzfaGQk wLnjRCgrHTyfXQEFjFJCMO...     18-24   Enterprise
# 2  zgNPmXBICRNbpjpTqIUWmMTeTYsInDNtAmzuxpDvcUZEAi...     45-54      Startup
# 3  LxeKzQFbPvhxXUSgPVlLLJ pUFaicjCgiMtAmsTjovkrdE...     45-54   Enterprise
# ...

# %%
df
# Out:
#           country        industry           ai_tool  adoption_rate  \
# 0             USA      Technology           ChatGPT          40.45
# 1          France   Manufacturing        Midjourney          35.72
# 2       Australia  Transportation           ChatGPT          13.47
# 3              UK   Manufacturing           ChatGPT          48.46
# 4              UK     Agriculture  Stable Diffusion          34.06
# ...           ...             ...               ...            ...
# 144995  Australia     Agriculture        Midjourney          86.93
# 144996    Germany       Education        Midjourney          51.99
# 144997        USA         Finance  Stable Diffusion          47.35
# 144998        USA          Retail           ChatGPT          31.87
# 144999     Canada      Technology            Claude          96.84
#
#         daily_active_users  year  \
# 0                     2461  2023
# 1                     8496  2024
# 2                     8641  2024
# ...

# %%
df_leading_industries = df['industry'].value_counts().head(10).reset_index(name='Count')

df_leading_industries
# Out:
#          industry  Count
# 0   Manufacturing  18267
# 1       Education  18200
# 2  Transportation  18158
# 3      Technology  18134
# 4         Finance  18124
# 5      Healthcare  18118
# 6          Retail  18053
# 7     Agriculture  17946

# %%
df_leading_regions = df['country'].value_counts().head(10).reset_index(name='Count')
df_leading_regions
# Out:
#        country  Count
# 0    Australia  14723
# 1       France  14676
# 2        China  14562
# 3  South Korea  14540
# 4        India  14531
# 5           UK  14476
# 6      Germany  14405
# 7       Brazil  14381
# 8       Canada  14354
# 9          USA  14352

# %%
fig, ax = plt.subplots(2,1)

sns.barplot(data=df_leading_industries, ax=ax[0], hue='Count', x='Count',y='industry', palette='dark:b_r')
ax[0].set_title('Top 10 Leading Industries in AI Adaptation')
ax[0].set_xlabel('Count')
ax[0].set_ylabel('')
ax[0].get_legend().set_visible(False)
ax[0].set_xlim(0,18500)

sns.barplot(data=df_leading_regions, ax=ax[1], hue='Count', x='Count',y='country', palette='dark:b_r')
ax[1].set_title('Top 10 Leading Regions in AI Adaptation')
ax[1].set_xlabel('Count')
ax[1].set_ylabel('')
ax[1].get_legend().set_visible(False)
ax[1].set_xlim(0,15000)

fig.tight_layout()
plt.show()
